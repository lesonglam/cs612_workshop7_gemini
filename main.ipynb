# %% [markdown]
# Testing the environment

# %%
a = "Success!"
a
# Out:
# 'Success!'

# %%
# !pip install -U google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (1.48.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-genai) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-genai) (2.42.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-genai) (2.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\letha\.conda\envs\ws7_gemini\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %%
import os
from dotenv import load_dotenv
from google import genai

# %%
# Load environment variables from the .env file
load_dotenv()

# Get API key from .env
api_key = os.getenv("GEMINI_API_KEY")

# Initialize Gemini client
client = genai.Client(api_key=api_key)

# Generate content
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain how AI works in a few sentences.",
)

print(response.text)
# Out:
# AI works by analyzing vast amounts of data using specialized algorithms. It "learns" by identifying patterns and relationships within this data during a training phase. Once trained, it uses these learned patterns to make predictions, decisions, or generate new information, often mimicking human-like intelligence.

# %%
client = genai.Client()
chat = client.chats.create(model="gemini-2.5-flash")

response = chat.send_message("I have 2 dogs in my house.")
print(response.text)

response = chat.send_message("How many paws are in my house?")
print(response.text)

for message in chat.get_history():
    print(f'role - {message.role}',end=": ")
    print(message.parts[0].text)
# Out:
# Oh, how wonderful! Two dogs can bring so much joy (and sometimes, a little chaos!).
#
# Do you want to tell me a bit about them? What are their names or breeds?
# Based on the two dogs you mentioned, that would be:
#
# 2 dogs * 4 paws/dog = **8 paws**
#
# Unless you have any other pets with paws that you haven't mentioned!
# role - user: I have 2 dogs in my house.
# role - model: Oh, how wonderful! Two dogs can bring so much joy (and sometimes, a little chaos!).
#
# Do you want to tell me a bit about them? What are their names or breeds?
# role - user: How many paws are in my house?
# role - model: Based on the two dogs you mentioned, that would be:
#
# 2 dogs * 4 paws/dog = **8 paws**
#
# Unless you have any other pets with paws that you haven't mentioned!

# %% [markdown]
# DOcs: https://ai.google.dev/gemini-api/docs/image-generation#python

# %%
from google import genai
from google.genai import types
from PIL import Image
from io import BytesIO

client = genai.Client()

prompt = (
    "Create a picture of a nano banana dish in a fancy restaurant with a Gemini theme"
)

response = client.models.generate_content(
    model="gemini-2.5-flash-image",
    contents=[prompt],
)

for part in response.candidates[0].content.parts:
    if part.text is not None:
        print(part.text)
    elif part.inline_data is not None:
        image = Image.open(BytesIO(part.inline_data.data))
        image.save("generated_image.png")
